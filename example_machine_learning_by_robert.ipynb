# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tseries.holiday import USFederalHolidayCalendar as calendarUSFH
import calendar
import seaborn as sns


# %matplotlib inline

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (12, 4)

# %%
trip_train = pd.read_csv('data/trip_train.csv',low_memory=False);
trip_test = pd.read_csv('data/trip_test.csv',low_memory=False);

# %%
trip_train = trip_train.iloc[:,:10]
trip_train.head(3)
# Out:
#        id  duration       start_date                    start_station_name  \
# 0  907649       396   8/27/2015 8:36  Harry Bridges Plaza (Ferry Building)
# 1  384043       636  7/28/2014 22:06                        Market at 10th
# 2  316176       334    6/9/2014 8:42                     Market at Sansome
#
#    start_station_id         end_date        end_station_name  end_station_id  \
# 0                50   8/27/2015 8:43  Embarcadero at Sansome              60
# 1                67  7/28/2014 22:17    Washington at Kearny              46
# 2                77    6/9/2014 8:47           2nd at Folsom              62
#
#    bike_id subscription_type
# 0      187        Subscriber
# 1      417        Subscriber
# 2      281        Subscriber

# %%
trip_test.shape
# Out:
# (119998, 10)

# %%
trip_train.shape
# Out:
# (549961, 11)

# %%
trip.shape[0] - trip_train.shape[0] - trip_test.shape[0]
# Out:
# 0

# %%
trip = pd.read_csv('data/trip.csv',low_memory=False);

# %%
trip
# Out:
#             id  duration       start_date  \
# 0         4576        63  8/29/2013 14:13
# 1         4607        70  8/29/2013 14:42
# 2         4130        71  8/29/2013 10:16
# 3         4251        77  8/29/2013 11:29
# 4         4299        83  8/29/2013 12:02
# 5         4927       103  8/29/2013 18:54
# 6         4500       109  8/29/2013 13:25
# 7         4563       111  8/29/2013 14:02
# 8         4760       113  8/29/2013 17:01
# 9         4258       114  8/29/2013 11:33
# 10        4549       125  8/29/2013 13:52
# 11        4498       126  8/29/2013 13:23
# 12        4965       129  8/29/2013 19:32
# 13        4557       130  8/29/2013 13:57
# 14        4386       134  8/29/2013 12:31
# 15        4749       138  8/29/2013 16:57
# 16        4242       141  8/29/2013 11:25
# 17        4329       142  8/29/2013 12:11
# 18        5097       142  8/29/2013 22:21
# 19        5084       144  8/29/2013 22:06
# 20        4982       146  8/29/2013 19:42
# ...

# %%
trip_test.head()
# Out:
#        id        start_date                        start_station_name  \
# 0  504737  10/18/2014 11:25                    Embarcadero at Sansome
# 1  530846   11/5/2014 13:00                     Embarcadero at Folsom
# 2  813140   6/18/2015 17:34  San Francisco Caltrain (Townsend at 4th)
# 3  897674    8/20/2015 7:06         Civic Center BART (7th at Market)
# 4  322830    6/13/2014 8:46   San Francisco Caltrain 2 (330 Townsend)
#
#    start_station_id          end_date               end_station_name  \
# 0                60  10/18/2014 12:12  Powell at Post (Union Square)
# 1                51   11/5/2014 13:09      Broadway St at Battery St
# 2                70   6/18/2015 17:37                2nd at Townsend
# 3                72    8/20/2015 7:15                Townsend at 7th
# 4                69    6/13/2014 8:57          Embarcadero at Folsom
#
#    end_station_id  bike_id subscription_type zip_code
# 0              71      426          Customer    77009
# ...

# %%
tripp = trip.iloc[:,0:1]
tested = pd.merge(tripp, trip_test, on ='id', how = 'right')
tested
# Out:
#             id       start_date  \
# 0         4130  8/29/2013 10:16
# 1         4498  8/29/2013 13:23
# 2         4557  8/29/2013 13:57
# 3         4386  8/29/2013 12:31
# 4         4242  8/29/2013 11:25
# 5         4550  8/29/2013 13:53
# 6         4917  8/29/2013 18:45
# 7         4841  8/29/2013 17:48
# 8         4704  8/29/2013 16:15
# 9         4824  8/29/2013 17:38
# 10        4638  8/29/2013 15:17
# 11        4081   8/29/2013 9:38
# 12        5001  8/29/2013 20:00
# 13        5002  8/29/2013 20:01
# 14        4423  8/29/2013 12:50
# 15        4743  8/29/2013 16:51
# 16        5057  8/29/2013 21:10
# 17        4595  8/29/2013 14:31
# 18        4959  8/29/2013 19:18
# 19        4331  8/29/2013 12:12
# 20        4744  8/29/2013 16:52
# 21        4941  8/29/2013 19:05
# 22        4647  8/29/2013 15:26
# 23        4300  8/29/2013 12:03
# 24        4968  8/29/2013 19:35
# 25        5075  8/29/2013 21:47
# 26        4570  8/29/2013 14:06
# 27        4278  8/29/2013 11:52
# ...

# %%
t
# Out:
#            id     start_date_x                           start_station_name_x  \
# 75       4080   8/29/2013 9:36                       South Van Ness at Market
# 11       4081   8/29/2013 9:38                        Mountain View City Hall
# 112      4100   8/29/2013 9:57                       South Van Ness at Market
# 0        4130  8/29/2013 10:16                        Mountain View City Hall
# 40       4199  8/29/2013 11:05                Grant Avenue at Columbus Avenue
# 90       4214  8/29/2013 11:15                Grant Avenue at Columbus Avenue
# 118      4218  8/29/2013 11:17       San Francisco Caltrain (Townsend at 4th)
# 130      4225  8/29/2013 11:18                             Powell Street BART
# 126      4241  8/29/2013 11:22                       South Van Ness at Market
# 4        4242  8/29/2013 11:25                             San Jose City Hall
# 101      4268  8/29/2013 11:40                                 Market at 10th
# ...

# %%
tt.shape
# Out:
# (119998, 10)

# %%
del t['start_date_x']
del t['start_date_x']
del t['start_date_x']
del t['start_date_x']
del t['start_date_x']
del t['start_date_x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-19d3eb7035d3> in <module>()
# ----> 1 del t['start_date_x','start_station_name_x']
#
# /Users/Robert/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __delitem__(self, key)
#    1640             # there was no match, this call should raise the appropriate
#    1641             # exception:
# -> 1642             self._data.delete(key)
#    1643
#    1644         # delete from the caches
#
# /Users/Robert/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in delete(self, item)
#    3600         Delete selected item (items if non-unique) in-place.
#    3601         """
# -> 3602         indexer = self.items.get_loc(item)
#    3603
#    3604         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ...

# %%
t.sort_values(by = 'id', ascending = 'false')
# Out:
#            id     start_date_x                           start_station_name_x  \
# 75       4080   8/29/2013 9:36                       South Van Ness at Market
# 11       4081   8/29/2013 9:38                        Mountain View City Hall
# 112      4100   8/29/2013 9:57                       South Van Ness at Market
# 0        4130  8/29/2013 10:16                        Mountain View City Hall
# 40       4199  8/29/2013 11:05                Grant Avenue at Columbus Avenue
# 90       4214  8/29/2013 11:15                Grant Avenue at Columbus Avenue
# 118      4218  8/29/2013 11:17       San Francisco Caltrain (Townsend at 4th)
# 130      4225  8/29/2013 11:18                             Powell Street BART
# 126      4241  8/29/2013 11:22                       South Van Ness at Market
# 4        4242  8/29/2013 11:25                             San Jose City Hall
# 101      4268  8/29/2013 11:40                                 Market at 10th
# ...
